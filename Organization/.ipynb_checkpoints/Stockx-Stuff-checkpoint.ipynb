# %%
import numpy as np
import pandas as pd
import getpass
from time import sleep

module_path = os.path.abspath(os.path.join('mod'))
sys.path = [x[0] for x in os.walk(module_path)] + sys.path
from stockxsdk import Stockx
from emailsdk import login, get_emails, order_df_creator

# %%
mail = login(input('Email: '), getpass.getpass('Password: '))
# Out:
# Login: OK

# %%
email_bodies = get_emails(mail)
df = order_df_creator(email_bodies)
df

# %% [markdown]
# # STOCKX STUFF

# %%
stockx = Stockx()
stockx.authenticate(input('Email: '), getpass.getpass('Password: '))

# %%
final_df = df_converter(df)
# Out:
# Airbrushed Floral Skateboard White
# Creeper Tee White
# Spotlight Keychain Clear
# Supreme/Frette Slippers White
# Buju Banton Tee White
# Supreme/Champion Chrome Crewneck Black
# Supreme/Swarovski Box Logo Tee Black
# Supreme/The North Face Arc Logo Denali Fleece Jacket Black
# Supreme/The North Face Arc Logo Mountain Parka Yellow
# Director's Chair Red
# Warm Up Crewneck Black
# Supreme/Steiff Bear Heather
# Cat in the Hat Tee White
# Supreme/The North Face Expedition Jacket Black
# Supreme/The North Face Expedition Backpack Black
# Supreme/The North Face Photo Tee Royal
# Supreme/Hanes Boxer Briefs (4 Pack) Black
# The Killer L/S Tee White
# Liquid Swords Tee White
# Waist Bag fw18 Black
# Backpack fw18 Purple
# Floral Logo Tee Black
# Madonna Tee Bright
# Liquid Tee Black
# Shoulder Bag fw18 Black
# Arabic Logo L/S Tee White
# Arabic Logo Neoprene Facemask Black
# Shoulder Bag ss18 Black
# Waist Bag ss18 Black
# Supreme/StatGear Pocket Samurai Red
# Supreme/Hanes Boxer Briefs (4 Pack) White
# Supreme/Spitfire Classic Swirl T-Shirt Black
# Rocks Tee Black
# Swimmers Tee Black

# %%
colorizer(final_df)
# Out:
# <style  type="text/css" >
#     #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col0 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col1 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col2 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col3 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col4 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col5 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col6 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col7 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col8 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col9 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col10 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow0_col11 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col0 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col1 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col2 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col3 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col4 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col5 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col6 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col7 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col8 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col9 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col10 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow1_col11 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col0 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col1 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col2 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col3 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col4 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col5 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col6 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col7 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col8 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col9 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col10 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow2_col11 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col0 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col1 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col2 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col3 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col4 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col5 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col6 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col7 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col8 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col9 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col10 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow3_col11 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col0 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col1 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col2 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col3 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col4 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col5 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col6 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col7 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col8 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col9 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col10 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow4_col11 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col0 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col1 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col2 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col3 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col4 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col5 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col6 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col7 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col8 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col9 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col10 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow5_col11 {
#             background-color:  LightPink;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow6_col0 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow6_col1 {
#             background-color:  Aquamarine;
#         }    #T_44fe3e3a_ad8d_11e9_ad69_d0817ac38fbarow6_col2 {
#             background-co
